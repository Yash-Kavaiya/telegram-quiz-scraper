# %%
import json

# Opening JSON file
f = open('result.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# Iterating through the json
print(data)

# Closing file
f.close()

dict2=data['messages']
print(len(dict2))
q=[]
o1=[]
o2=[]
o3=[]
o4=[]
for i in range(0,200):
    print(dict2[i]['poll']["question"][7:])
    q.append(dict2[i]['poll']["question"][7:])
    
    print((dict2[i]['poll']["answers"][0]["text"]))
    
    o1.append(dict2[i]['poll']["answers"][0]["text"])
    
    if (len(dict2[i]['poll']["answers"]))>1:
        o2.append(dict2[i]['poll']["answers"][1]["text"])
    else:
        o2.append("-")
    
    if len(dict2[i]['poll']["answers"])>2:
        o3.append(dict2[i]['poll']["answers"][2]["text"])
    else:
        o3.append("-")
        
    if len(dict2[i]['poll']["answers"])>3:   
        o4.append(dict2[i]['poll']["answers"][3]["text"])
    else:
        o4.append("-")
    
print(len(q),len(o1),len(o2),len(o3),len(o4))
import pandas as pd

# dictionary of lists 
dict8 = {'Question': q, 'option1': o1,'option2': o2,'option3': o3,'option4': o4 } 
    
df = pd.DataFrame(dict8)
print(df)
df.to_csv('ગુજરાતી વ્યાકરણો.tsv', sep="\t")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_37/2747046635.py in <module>
#       6 # returns JSON object as
#       7 # a dictionary
# ----> 8 data = json.load(f)
#       9
#      10 # Iterating through the json
#
# /opt/conda/lib/python3.9/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# /opt/conda/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
# ...

# %% [markdown]
# # gset
#
# Use the "Run" button to execute the code.

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
# Execute this to save new versions of the notebook
jovian.commit(project="gset")
# Out:
# [jovian] Error: Failed to read the Jupyter notebook. Please re-run this cell to try again. If the issue persists, provide the "filename" argument to "jovian.commit" e.g. "jovian.commit(filename='my-notebook.ipynb')"

# %%
import json

# Opening JSON file
f = open('result.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# Iterating through the json
print(data)

# Closing file
f.close()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data['messages']
# Out:
# [{'id': 2560,
#   'type': 'message',
#   'date': '2022-08-30T17:28:44',
#   'date_unixtime': '1661860724',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[1/101] કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'અમરેલી', 'voters': 0, 'chosen': False},
#     {'text': 'બોટાદ', 'voters': 0, 'chosen': False},
#     {'text': 'ભાવનગર', 'voters': 1, 'chosen': True},
#     {'text': 'સુરત', 'voters': 0, 'chosen': False}]},
#   'text': ''},
#  {'id': 2561,
#   'type': 'message',
#   'date': '2022-08-30T17:29:02',
#   'date_unixtime': '1661860742',
#   'from': 'Quiz Bot',
#   'from_id': 'user983000232',
#   'poll': {'question': '[2/101] અમરતકાકી – કઈ કૃતિનું પાત્ર છે?',
#    'closed': True,
#    'total_voters': 1,
#    'answers': [{'text': 'જનમટીપ', 'voters': 0, 'chosen': False},
#     {'text': 'લોહીની સગાઈ', 'voters': 0, 'chosen': False},
#     {'text': 'શરણાઈના સૂર', 'voters': 1, 'chosen': True},
# ...

# %%
len(data['messages'])
# Out:
# 101

# %%
dict2=data['messages']

# %%
len(dict2)
# Out:
# 101

# %%
for i in dict2:
    a=i
    s={}
   # print(a.keys())
    if a.keys=="['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'poll', 'text']":
        print(a.keys())
        
    a=[]

# %%
dict2[5]['poll']["answers"][1]["text"]
# Out:
# '8 જુલાઈ'

# %%
for i in dict2:
        for x in i.values():
            print(x)
# Out:
# 2674
# message
# 2022-08-31T10:53:17
# 1661923397
# Data GURU
# user5513588440
# [{'type': 'bot_command', 'text': '/start'}]
# 2678
# message
# 2022-08-31T10:53:25
# 1661923405
# Quiz Bot
# user983000232
# {'question': '[1/101] બ્રેકેટમાં  આપેલ શબ્દનો અલંકાર જણાવો.                              પુષ્પાની  હથેળી એટલે જાણે કમળની પાંદડીઓ (જાણે)', 'closed': True, 'total_voters': 1, 'answers': [{'text': 'ઉત્પ્રેક્ષા અલંકાર', 'voters': 0, 'chosen': False}, {'text': 'રૂપક અલંકાર', 'voters': 1, 'chosen': True}, {'text': 'વ્યતિરેક અલંકાર', 'voters': 0, 'chosen': False}, {'text': 'સજીવારોપણ અલંકાર', 'voters': 0, 'chosen': False}]}
#
# 2679
# message
# 2022-08-31T10:53:34
# 1661923414
# Quiz Bot
# user983000232
# ...

# %%
q=[]
o1=[]
o2=[]
o3=[]
o4=[]
for i in range(1,101):
    print(dict2[i]['poll']["question"][8:])
    q.append(dict2[i]['poll']["question"][8:])
    
    print((dict2[i]['poll']["answers"][0]["text"]))
    
    o1.append(dict2[i]['poll']["answers"][0]["text"])
    
    if (len(dict2[i]['poll']["answers"]))>1:
        o2.append(dict2[i]['poll']["answers"][1]["text"])
    else:
        o2.append("-")
    if len(dict2[i]['poll']["answers"])>2:
        o3.append(dict2[i]['poll']["answers"][2]["text"])
    else:
        o3.append("-")
    pdf.cell(200, 10, txt = o3[i]) 
    if len(dict2[i]['poll']["answers"])>3:   
        o4.append(dict2[i]['poll']["answers"][3]["text"])
    else:
        o4.append("-")
# Out:
# બ્રેકેટમાં  આપેલ શબ્દનો અલંકાર જણાવો.                              પુષ્પાની  હથેળી એટલે જાણે કમળની પાંદડીઓ (જાણે)
# ઉત્પ્રેક્ષા અલંકાર
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_37/3499310269.py in <module>
#      20     else:
#      21         o3.append("-")
# ---> 22     pdf.cell(200, 10, txt = o3[i])
#      23     if len(dict2[i]['poll']["answers"])>3:
#      24         o4.append(dict2[i]['poll']["answers"][3]["text"])
#
# NameError: name 'pdf' is not defined

# %%
que=[]
op1=[]
op2=[]
op3=[]
op4=[]

for i in dict2:
    if 'poll' in i:
        que.append(i['poll']["question"][8:])
        try:
            op1.append(i["poll"]["answers"][0]["text"])
        except:
            op1.append(None)
        try:
            op2.append(i["poll"]["answers"][1]["text"])
        except:
            op2.append(None)
        try:
            op3.append(i["poll"]["answers"][2]["text"])
        except:
            op3.append(None)
        try:
            op4.append(i["poll"]["answers"][3]["text"])
        except:
            op4.append(None)
dict89 = {'Question': que, 'option1': op1,'option2': op2,'option3': op3,'option4': op4 } 
    
df2 = pd.DataFrame(dict89)
    
df2 
                
        
#         for j,k in  enumerate(i["poll"]["answers"]):
#             dic[i['poll']["question"][8:]][j]=k["text"]
# dic
# Out:
#                                              Question  \
# 0   બ્રેકેટમાં  આપેલ શબ્દનો અલંકાર જણાવો.         ...
# 1   સમાર્ટ સીટી એવોર્ડ 2021 બાબતે કયું વિધાન ખોટું...
# 2                         GSLV નું પૂરું નામ શું છે ?
# 3        વિશ્વ પૃથ્વી દિવસ ક્યારે  મનાવવામાં આવે છે ?
# 4       વિશ્વ પર્યાવરણ દિવસ ક્યારે મનાવવામાં આવે છે ?
# ..                                                ...
# 95                         32% ને અપૂર્ણાંકમાં ફેરવો.
# 96   કેતનને એક પરિક્ષામાં 400 માર્ક્સ આવે છે જો તે...
# 97   જો એક બોક્સમાં રહેલ 1200 ફૂલમાંથી 62% ફૂલ ગુલ...
# 98   ભુરાને 10માંની પરિક્ષામાં 700 માંથી 280 માર્ક...
# 99  ] સંપૂર્ણ ભરાયેલી ટાંકીને ખાલી કરવા માટે નળ P,...
#
#                                               option1  \
# 0                                  ઉત્પ્રેક્ષા અલંકાર
# 1   આ એવોર્ડની જાહેરાત 25 જૂન 2020 ના રોજ કરવામાં ...
# 2                 Ground Satellite Launching Vechicle
# 3                                              10 જૂન
# ...

# %%
dict2[2]['poll']["answers"][1]["text"]
# Out:
# 'આ એવોર્ડ  સામાજિક બાબતો, શાસન, શહેરી પર્યાવરણ પાણી અને શહેરી ગતિશીલતા થીમ અથવા વિષય હેઠળ અપાય આવે છે'

# %%
dict2[4]['poll']["answers"][1]["text"]
# Out:
# '22'

# %%
o1
# Out:
# ['અમરેલી',
#  'જનમટીપ',
#  'દીપ નિર્વાણ',
#  'કવીશ્વર = કવિ + ઈશ્વર',
#  '19',
#  '30',
#  '41',
#  '3',
#  '20480',
#  'દેશપ્રેમ',
#  'ભવસાગર',
#  'પૃથ્વી',
#  'અનુ. 245 – 255',
#  '708',
#  'ઓરિસ્સા',
#  'લોકસભાના અધ્યક્ષ બને છે',
#  'My name is asked by them',
#  'elixir',
#  'Odour',
#  '1961',
#  'રાજસ્થાન',
#  '1994',
#  'બારડોલી',
#  'જમશેદજી તાતા',
#  'નડિયાદ',
#  'બોટાદ',
#  'પ્રથમ',
#  '14',
#  'ભારતીય પ્રશાસનિક સેવા',
#  'ભૂરો',
#  'ઉત્પ્રેક્ષા',
#  'સમ્ + નિ + _આસ્તી',
#  'દર્શક',
#  'ચંદ્રકાંત બક્ષી',
#  'દ્વન્દ્વ',
#  'હિંદ મહાસાગર',
#  'મદન મોહન માલવીયા',
#  'સ્વિટઝર્લેન્ડ',
#  'સપ્ટેમ્બર',
#  'My',
#  'had been served',
#  'Book',
#  'fondle',
#  'On',
#  '1, 2, 3',
#  'ઉત્તર',
#  '35%',
#  '12:5',
#  '18',
#  '9207716',
#  'ન ર મ ર સ લ ગા',
#  'અસમ',
#  'ઈરાક',
#  'બંગાળ',
#  'પોખરણ',
#  '1950',
#  'સિદ્ધરાજ જયસિંહ',
#  'અવંતિકા',
#  'લાલટ',
#  '1951',
#  'મેગેસ્થનીઝ',
#  'So that',
#  'Meditate',
#  'વિધ્યાથૅ કુંદત',
#  'અવલી',
#  'દલપતરામ',
#  'પી વી સિંધુ',
# ...

# %%
import pandas as pd

# %%
from fpdf import FPDF
pdf = FPDF()
 
# Add a page
pdf.add_page()
pdf.set_font("Arial", size = 15)

pdf.cell(200, 10, txt = "GeeksforGeeks")
pdf.output("GFG.pdf")
# Out:
# ''

# %%
# dictionary of lists 
dict8 = {'Question': q, 'option1': o1,'option2': o2,'option3': o3,'option4': o4 } 
    
df = pd.DataFrame(dict8)
    
df
# Out:
#                                              Question                option1  \
# 0                કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?                 અમરેલી
# 1                     અમરતકાકી – કઈ કૃતિનું પાત્ર છે?                 જનમટીપ
# 2   ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યુ...            દીપ નિર્વાણ
# 3                        નીચેનામાંથી ખોટી સંધિ જણાવો.  કવીશ્વર = કવિ + ઈશ્વર
# 4   એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ ...                     19
# ..                                                ...                    ...
# 95                      પાણીની ઘનતા સૌથી વધુ હોય છે ?               100સે પર
# 96   પસંદ કરેલ 7 આડી રો તથા 9 ઊભી હરોળ ની હદ માટે ...                   9C7R
# 97   ભારતમાં ગ્રુહ વપરાશ માટે AC વોલ્ટેજ નું મૂલ્ય...           110 v, 60 Hz
# 98             નીચેના માંથી એરીથમેટિક ઓપરેશન. ક્યાં.?              +  અને  -
# 99   ] સ્વાવલંબી પોષણ પદ્ધત્તિ માં શાની જરૂર હોય છે ?           CO² અને પાણી
#
# ...

# %%
df.to_csv('તલાટી અને જુનિયર કલાર્ક મોડેલ પેપર -6.tsv', sep="\t")

# %%
for i in range(100):
    print("",(i+1),") " , q[i])
    print("(A) ",o1[i])
    print("(B) " ,o2[i])
    print("(C) ",o3[i])
    print("(D) ",o4[i])
    print("\n")
# Out:
# ( 1 )  કવિ રમેશ પારેખનો જન્મ ક્યાં થયો હતો?
# (A)  અમરેલી
# (B)  બોટાદ
# (C)  ભાવનગર
# (D)  સુરત
#
#
# ( 2 )  અમરતકાકી – કઈ કૃતિનું પાત્ર છે?
# (A)  જનમટીપ
# (B)  લોહીની સગાઈ
# (C)  શરણાઈના સૂર
# (D)  જુમો ભિસ્તી
#
#
# ( 3 )  ગોપાળબાપા’ પ્રકરણ કઈ નવલકથામાંથી લેવામાં આવ્યું છે?
# (A)  દીપ નિર્વાણ
# (B)  સોક્રેટીસ
# (C)  ઝેર તો પીધા છે જાણી જાણી
# (D)  કુરુક્ષેત્ર
#
#
# ( 4 )  નીચેનામાંથી ખોટી સંધિ જણાવો.
# (A)  કવીશ્વર = કવિ + ઈશ્વર
# (B)  પૂર્વોક્ત = પૂર્વ + ઊક્ત
# (C)  ઉપેન્દ્ર = ઉપ + ઈન્દ્ર
# (D)  રવીન્દ્ર = રવિ + ઈન્દ્ર
#
#
# ( 5 )  એક સમાંતર શ્રેણીનું પ્રથમ પદ 5 અને છેલ્લું પદ 45 છે અને બધા પદોનો સરવાળો 500 હોય તો પદોની સંખ્યા કેટલી હશે?
# (A)  19
# (B)  22
# (C)  21
# (D)  20
#
#
# ( 6 )  વેપારી પોતાના માલ પર 20% અને 10% એમ બે ક્રમિક વળતર આપે છે. પરિણામી વળતર કેટલું થાય?
# (A)  30
# (B)  22
# (C)  28
# (D)  20
#
#
# ( 7 )  રાહીનું સ્થાન વર્ગમાં ઉપરથી 16મું અને નીચેથી 24મું છે, તો વર્ગમાં કુલ કેટલા વિદ્યાર્થીઓ હશે?
# (A)  41
# (B)  39
# (C)  40
# (D)  38
#
#
# ...

# %%
dic
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
for i in dict2:
    if 'poll' in i:
         print(i['poll']["answers"][1]["text"])
# Out:
# રૂપક અલંકાર
# આ એવોર્ડ  સામાજિક બાબતો, શાસન, શહેરી પર્યાવરણ પાણી અને શહેરી ગતિશીલતા થીમ અથવા વિષય હેઠળ અપાય આવે છે
# Gesoynchronous Satellite Launching Vecvhicle
# 21 જૂન
# 8 જુલાઈ
# ખેડા
# New
# ડિસ્ક થ્રો
# ટોળી વિખેરવા
# 321
# સામાજિક
# ચેન્નાઇ સુપર કિંગ્સ
# પાણીમાં
# Modulation Demodulation
# તે લોકસભામાં અથવા વિધાનસભાની ચૂંટણીમાં 4% વોટ પ્રાપ્ત કરે છે
# indirail.gov.in
# ભારતીય પુરાતત્વ સર્વેક્ષણ
# 14
# ટેલી કોન્ફરન્સ
# 1971
# 63
# બંગભંગની લડત
# 10
# 73
# ઉપરાષ્ટ્રપતિ
# 6 અઠવાડિયાને અંતે
# 6
# GB
# ALY
# સુમેળના અભાવે કામ સિદ્ધ ના થાય
# ઇલોરની ગુફાઓ
# મુંબઈ
# ડેલહાઉસી
# અમાત્યાસ
# 10%
# માત્ર સજીવ જીવતંત્ર અને માટીના કણ
# 105
# 318  (દ)
# 318  (દ)
# 181
# 13 જાન્યુઆરી 1956
# ધીરુભાઈ ઠાકર
# ગુજરાત સાહિત્ય સભા
# વારીસ અલવી
# શ્રી જીવરામ જોષી
# ઉમાશંકર જોષી
# ઝવેચંદ મેધાણી
# ઝીણાભાઈ દેસાઈ
# બકુલ ત્રિપાઠી
# પન્નાલાલ પટેલ
# ઝવેચંદ મેધાણી
# બ. ક. ઠાકોર
# મહાત્મા ગાંધી
# પીતાંબર પટેલ
# અકોટો મિત્ર
# આટલો ગરીબ ; ચંદાને દયા આવી.
# સવિનય જણાવવાનું કે.........
# સંભાવનાર્થ
# આજ્ઞાર્થ
# ...

# %%
import pandas as pd
# dictionary of lists 

df1 = pd.DataFrame(dic)
    
df1
# Out:
#   બ્રેકેટમાં  આપેલ શબ્દનો અલંકાર જણાવો.                              પુષ્પાની  હથેળી એટલે જાણે કમળની પાંદડીઓ (જાણે)  \
# 0                                 ઉત્પ્રેક્ષા અલંકાર
# 1                                        રૂપક અલંકાર
# 2                                    વ્યતિરેક અલંકાર
# 3                                   સજીવારોપણ અલંકાર
#
#   સમાર્ટ સીટી એવોર્ડ 2021 બાબતે કયું વિધાન ખોટું છે ?  \
# 0  આ એવોર્ડની જાહેરાત 25 જૂન 2020 ના રોજ કરવામાં ...
# 1  આ એવોર્ડ  સામાજિક બાબતો, શાસન, શહેરી પર્યાવરણ ...
# 2  આ એવોર્ડમાં ટોચના પરફોર્મીંગ સીટી તરીકે સુરત શ...
# 3  આ એવોર્ડ અંતર્ગત ચંદીગઢને શ્રેષ્ઠ કેન્દ્રસાશિત...
#
#                     GSLV નું પૂરું નામ શું છે ?  \
# 0           Ground Satellite Launching Vechicle
# 1  Gesoynchronous Satellite Launching Vecvhicle
# 2        Gravity Synchronous Launching Vechicle
# 3            Group Satellite Launching Vechicle
#
#   વિશ્વ પૃથ્વી દિવસ ક્યારે  મનાવવામાં આવે છે ?  \
# 0                                       10 જૂન
# ...

# %%
df1.to_csv('તલાટી.tsv', sep="\t")
